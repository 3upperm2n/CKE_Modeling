# %%
import pandas as pd
import numpy as np

# %%
trace_file = "nvprof_gputrace.csv"

## skip the 1st three rows
df_trace = pd.read_csv(trace_file, skiprows=3)

# %%
#df_trace
# Out:
#          Start  Duration  Grid X  Grid Y  Grid Z  Block X  Block Y  Block Z  \
# 0           ms        ms     NaN     NaN     NaN      NaN      NaN      NaN
# 1   223.867782  0.692071     NaN     NaN     NaN      NaN      NaN      NaN
# 2   224.561069  0.696358     NaN     NaN     NaN      NaN      NaN      NaN
# 3   225.258707  0.728486     NaN     NaN     NaN      NaN      NaN      NaN
# 4   225.283731  0.145537  4096.0     1.0     1.0    256.0      1.0      1.0
# 5   225.437461  0.756422     NaN     NaN     NaN      NaN      NaN      NaN
# 6   225.989914  2.813145     NaN     NaN     NaN      NaN      NaN      NaN
# 7   226.312636  0.691303     NaN     NaN     NaN      NaN      NaN      NaN
# 8   227.005219  2.141875     NaN     NaN     NaN      NaN      NaN      NaN
# 9   227.366694  0.690726     NaN     NaN     NaN      NaN      NaN      NaN
# 10  228.058636  1.451021     NaN     NaN     NaN      NaN      NaN      NaN
# 11  228.812659  0.146273  4096.0     1.0     1.0    256.0      1.0      1.0
# 12  228.972500  0.730503     NaN     NaN     NaN      NaN      NaN      NaN
# 13  229.167286  0.153185  4096.0     1.0     1.0    256.0      1.0      1.0
# 14  229.517817  0.144769  4096.0     1.0     1.0    256.0      1.0      1.0
# 15  229.704283  0.659718     NaN     NaN     NaN      NaN      NaN      NaN
# 16  230.365249  0.658758     NaN     NaN     NaN      NaN      NaN      NaN
#
#     Registers Per Thread Static SMem Dynamic SMem      Size Throughput  \
# 0                    NaN           B            B        MB       GB/s
# 1                    NaN         NaN          NaN  4.000000   5.644291
# 2                    NaN         NaN          NaN  4.000000   5.609543
# 3                    NaN         NaN          NaN  4.000000   5.362148
# 4                    8.0           0            0       NaN        NaN
# 5                    NaN         NaN          NaN  4.000000   5.164115
# 6                    NaN         NaN          NaN  4.000000   1.388570
# 7                    NaN         NaN          NaN  4.000000   5.650561
# 8                    NaN         NaN          NaN  4.000000   1.823753
# 9                    NaN         NaN          NaN  4.000000   5.655282
# 10                   NaN         NaN          NaN  4.000000   2.692070
# 11                   8.0           0            0       NaN        NaN
# 12                   NaN         NaN          NaN  4.000000   5.347343
# 13                   8.0           0            0       NaN        NaN
# 14                   8.0           0            0       NaN        NaN
# 15                   NaN         NaN          NaN  4.000000   5.921091
# 16                   NaN         NaN          NaN  4.000000   5.929719
#
#                  Device  Context  Stream  \
# 0                   NaN      NaN     NaN
# 1   GeForce GTX 950 (0)      1.0    13.0
# 2   GeForce GTX 950 (0)      1.0    13.0
# 3   GeForce GTX 950 (0)      1.0    16.0
# 4   GeForce GTX 950 (0)      1.0    13.0
# 5   GeForce GTX 950 (0)      1.0    13.0
# 6   GeForce GTX 950 (0)      1.0    16.0
# 7   GeForce GTX 950 (0)      1.0    14.0
# 8   GeForce GTX 950 (0)      1.0    14.0
# 9   GeForce GTX 950 (0)      1.0    15.0
# 10  GeForce GTX 950 (0)      1.0    15.0
# 11  GeForce GTX 950 (0)      1.0    16.0
# 12  GeForce GTX 950 (0)      1.0    16.0
# 13  GeForce GTX 950 (0)      1.0    14.0
# 14  GeForce GTX 950 (0)      1.0    15.0
# 15  GeForce GTX 950 (0)      1.0    14.0
# 16  GeForce GTX 950 (0)      1.0    15.0
#
#                                                  Name
# 0                                                 NaN
# 1                                  [CUDA memcpy HtoD]
# 2                                  [CUDA memcpy HtoD]
# 3                                  [CUDA memcpy HtoD]
# 4   kernel_vectorAdd(float const *, float const *,...
# 5                                  [CUDA memcpy DtoH]
# 6                                  [CUDA memcpy HtoD]
# 7                                  [CUDA memcpy HtoD]
# 8                                  [CUDA memcpy HtoD]
# 9                                  [CUDA memcpy HtoD]
# 10                                 [CUDA memcpy HtoD]
# 11  kernel_vectorAdd(float const *, float const *,...
# 12                                 [CUDA memcpy DtoH]
# 13  kernel_vectorAdd(float const *, float const *,...
# 14  kernel_vectorAdd(float const *, float const *,...
# 15                                 [CUDA memcpy DtoH]
# 16                                 [CUDA memcpy DtoH]

# %%
rows, cols = df_trace.shape
# print rows
# print cols

start_unit = df_trace['Start'].iloc[0]
# print start_unit

duration_unit = df_trace['Duration'].iloc[0]
# print duration_unit


start_coef =  1.0

if start_unit == 's':
    start_coef = 1e3
    
if start_unit == 'us':
    start_coef = 1e-3
    
# print start_coef


duration_coef =  1.0

if duration_unit == 's':
    duration_coef = 1e3
    
if duration_unit == 'us':
    duration_coef = 1e-3
    
# print duration_coef

# read the row 1 for the starting time
start_time = df_trace['Start'].iloc[1]
# print type(start_time)
start_time = float(start_time) * start_coef
# print start_time


# read the last row  for the starting time
end_time = df_trace['Start'].iloc[rows-1]
end_dur_time = df_trace['Duration'].iloc[rows-1]
# print type(end_time)
# print type(end_dur_time)
# print end_time
# print end_dur_time
end_time = float(end_time) * start_coef
end_dur_time = float(end_dur_time) * duration_coef

end_time = end_time + end_dur_time

# print end_time

#---------------------------------
# total runtime
#---------------------------------
runtime = end_time - start_time
print "runtime : " + str(runtime) + " ms"
# Out:
# runtime : 7.156225 ms
